# %% [markdown]
# ## Import Libararies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Import Data

# %%
kenya_pop_df= pd.read_csv("pop_df.csv")
kenya_educ_df= pd.read_csv("updated_education_df.csv")
rwanda_pop_df= pd.read_csv("Rpop_df.csv")
rwanda_educ_df= pd.read_csv("Rwanda_updated_education_df.csv")
ghana_pop_df= pd.read_csv("Gpop_df.csv")
ghana_educ_df= pd.read_csv("Ghana_updated_education_df.csv")

# %%
kenya_pop_df.shape
# Out:
# (40, 31)

# %%
kenya_pop_df.head()
# Out:
#     name age_group     sex  year  population  ILO_inactive_share  \
# 0  Kenya     15-24  female  2015   4742700.0              55.928
# 1  Kenya     15-24  female  2016   4887980.0              56.361
# 2  Kenya     15-24  female  2017   5033260.0              56.906
# 3  Kenya     15-24  female  2018   5178540.0              57.463
# 4  Kenya     15-24  female  2019   5323820.0              58.043
#
#    total_inactive_population  ILO_unemployed_rate  \
# 0               2.652497e+06                7.339
# 1               2.754914e+06                7.371
# 2               2.864227e+06                9.304
# 3               2.975744e+06               11.192
# 4               3.090105e+06               13.175
#
#    total_unemployed_population  total_employed_population  ...    Real estate  \
# 0                153399.979382               1.936803e+06  ...       0.000000
# 1                157228.264801               1.975837e+06  ...  485418.609963
# ...

# %%
kenya_educ_df.head()
# Out:
#     name age_group     sex  year  population  total_inactive_population  \
# 0  Kenya     15-24  female  2015   4742700.0               2.652497e+06
# 1  Kenya     15-24  female  2016   4887980.0               2.754914e+06
# 2  Kenya     15-24  female  2017   5033260.0               2.864227e+06
# 3  Kenya     15-24  female  2018   5178540.0               2.975744e+06
# 4  Kenya     15-24  female  2019   5323820.0               3.090105e+06
#
#    total_unemployed_population  total_employed_population  \
# 0                153399.979382               1.936803e+06
# 1                157228.264801               1.975837e+06
# 2                201806.836312               1.967226e+06
# 3                246536.879053               1.956259e+06
# 4                294291.971987               1.939423e+06
#
#    Less than basic_inactive  Basic_inactive  Intermediate_inactive  \
# 0                       NaN             NaN                    NaN
# ...

# %%
kenya_educ_df.tail()
# Out:
#      name age_group   sex  year   population  total_inactive_population  \
# 35  Kenya     25-35  male  2020  4493127.680              354193.255014
# 36  Kenya     25-35  male  2021  4598833.344              326425.190757
# 37  Kenya     25-35  male  2022  4704539.008              315110.022756
# 38  Kenya     25-35  male  2023  4810244.672              320699.012282
# 39  Kenya     25-35  male  2024  4915950.336              327451.451881
#
#     total_unemployed_population  total_employed_population  \
# 35                154009.749954               3.984925e+06
# 36                157950.929425               4.114457e+06
# 37                154464.005991               4.234965e+06
# 38                155562.757109               4.333983e+06
# 39                156743.121882               4.431756e+06
#
#     Less than basic_inactive  Basic_inactive  Intermediate_inactive  \
# 35              7.710787e+06    3.226701e+06           2.833546e+06
# ...

# %%
# show information int dataset
kenya_educ_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   name                           40 non-null     object
#  1   age_group                      40 non-null     object
#  2   sex                            40 non-null     object
#  3   year                           40 non-null     int64
#  4   population                     40 non-null     float64
#  5   total_inactive_population      40 non-null     float64
#  6   total_unemployed_population    40 non-null     float64
#  7   total_employed_population      40 non-null     float64
#  8   Less than basic_inactive       28 non-null     float64
#  9   Basic_inactive                 28 non-null     float64
#  10  Intermediate_inactive          28 non-null     float64
#  11  Advanced_inactive              28 non-null     float64
# ...

# %% [markdown]
# ## Data Cleaning

# %%
kenya_educ_df.describe()
# Out:
#               year    population  total_inactive_population  \
# count    40.000000  4.000000e+01               4.000000e+01
# mean   2019.500000  4.949874e+06               1.764240e+06
# std       2.908872  5.789395e+05               1.356035e+06
# min    2015.000000  4.085026e+06               2.682637e+05
# 25%    2017.000000  4.481412e+06               5.038431e+05
# 50%    2019.500000  4.867160e+06               1.582808e+06
# 75%    2022.000000  5.385925e+06               3.114913e+06
# max    2024.000000  6.063980e+06               3.504664e+06
#
#        total_unemployed_population  total_employed_population  \
# count                    40.000000               4.000000e+01
# mean                 194167.781127               2.991466e+06
# std                   93811.300702               9.686359e+05
# min                   51678.961106               1.936383e+06
# 25%                  137945.308701               2.056416e+06
# ...

# %%
kenya_pop_df.describe()
# Out:
#               year    population  ILO_inactive_share  \
# count    40.000000  4.000000e+01           40.000000
# mean   2019.500000  4.949874e+06           33.440600
# std       2.908872  5.789395e+05           23.952124
# min    2015.000000  4.085026e+06            6.499000
# 25%    2017.000000  4.481412e+06           10.676000
# 50%    2019.500000  4.867160e+06           33.944500
# 75%    2022.000000  5.385925e+06           57.377500
# max    2024.000000  6.063980e+06           58.456000
#
#        total_inactive_population  ILO_unemployed_rate  \
# count               4.000000e+01            40.000000
# mean                1.764240e+06             7.184575
# std                 1.356035e+06             4.718381
# min                 2.682637e+05             1.347000
# 25%                 5.038431e+05             3.392500
# 50%                 1.582808e+06             5.618000
# 75%                 3.114913e+06            12.381750
# ...

# %%
# Check for null values
kenya_educ_df.isnull().sum()
# Out:
# name                              0
# age_group                         0
# sex                               0
# year                              0
# population                        0
# total_inactive_population         0
# total_unemployed_population       0
# total_employed_population         0
# Less than basic_inactive         12
# Basic_inactive                   12
# Intermediate_inactive            12
# Advanced_inactive                12
# Level not stated_inactive        12
# Less than basic_unemployment     32
# Basic_unemployment               32
# Intermediate_unemployment        32
# Advanced_unemployment            32
# Level not stated_unemployment    32
# dtype: int64

# %%
#Checking the percentage of null values per column
kenya_educ_df.isnull().sum()/len(kenya_educ_df)
# Out:
# name                             0.0
# age_group                        0.0
# sex                              0.0
# year                             0.0
# population                       0.0
# total_inactive_population        0.0
# total_unemployed_population      0.0
# total_employed_population        0.0
# Less than basic_inactive         0.3
# Basic_inactive                   0.3
# Intermediate_inactive            0.3
# Advanced_inactive                0.3
# Level not stated_inactive        0.3
# Less than basic_unemployment     0.8
# Basic_unemployment               0.8
# Intermediate_unemployment        0.8
# Advanced_unemployment            0.8
# Level not stated_unemployment    0.8
# dtype: float64

# %% [markdown]
# *The percentages of the null values is not that large, therefore we cannot drop columns*

# %%
# Compute the mean for each column in the DataFrame
mean_df = kenya_educ_df.mean()

# Print the mode DataFrame
mean_df
# Out:
# year                             2.019500e+03
# population                       4.949874e+06
# total_inactive_population        1.764240e+06
# total_unemployed_population      1.941678e+05
# total_employed_population        2.991466e+06
# Less than basic_inactive         7.840149e+07
# Basic_inactive                   8.244775e+07
# Intermediate_inactive            6.451520e+07
# Advanced_inactive                3.483041e+07
# Level not stated_inactive        8.475121e+07
# Less than basic_unemployment     1.460892e+05
# Basic_unemployment               9.113975e+05
# Intermediate_unemployment        5.567463e+05
# Advanced_unemployment            4.329913e+04
# Level not stated_unemployment    5.663887e+03
# dtype: float64

# %%
median_df = kenya_educ_df.median()
median_df
# Out:
# year                             2.019500e+03
# population                       4.867160e+06
# total_inactive_population        1.582808e+06
# total_unemployed_population      1.589283e+05
# total_employed_population        2.868012e+06
# Less than basic_inactive         2.099649e+07
# Basic_inactive                   1.034755e+07
# Intermediate_inactive            1.159216e+07
# Advanced_inactive                8.472269e+06
# Level not stated_inactive        2.772743e+07
# Less than basic_unemployment     1.215515e+05
# Basic_unemployment               8.161377e+05
# Intermediate_unemployment        4.824237e+05
# Advanced_unemployment            3.461840e+04
# Level not stated_unemployment    4.462407e+03
# dtype: float64

# %%
#imputing the remaining null values with mean
for i in kenya_educ_df.columns[kenya_educ_df.isnull().any(axis=0)]:
  kenya_educ_df[i].fillna(kenya_educ_df[i].mean(),inplace=True)

# %%
kenya_educ_df.columns
# Out:
# Index(['name', 'age_group', 'sex', 'year', 'population',
#        'total_inactive_population', 'total_unemployed_population',
#        'total_employed_population', 'Less than basic_inactive',
#        'Basic_inactive', 'Intermediate_inactive', 'Advanced_inactive',
#        'Level not stated_inactive', 'Less than basic_unemployment',
#        'Basic_unemployment', 'Intermediate_unemployment',
#        'Advanced_unemployment', 'Level not stated_unemployment'],
#       dtype='object')

# %% [markdown]
# ***Lets take a look at the population data frame and see what trends we can find in the current employment trends for the Kenyan IT sector nationally and by demographics***

# %%
kenya_pop_df.head()
# Out:
#     name age_group     sex  year  population  ILO_inactive_share  \
# 0  Kenya     15-24  female  2015   4742700.0              55.928
# 1  Kenya     15-24  female  2016   4887980.0              56.361
# 2  Kenya     15-24  female  2017   5033260.0              56.906
# 3  Kenya     15-24  female  2018   5178540.0              57.463
# 4  Kenya     15-24  female  2019   5323820.0              58.043
#
#    total_inactive_population  ILO_unemployed_rate  \
# 0               2.652497e+06                7.339
# 1               2.754914e+06                7.371
# 2               2.864227e+06                9.304
# 3               2.975744e+06               11.192
# 4               3.090105e+06               13.175
#
#    total_unemployed_population  total_employed_population  ...    Real estate  \
# 0                153399.979382               1.936803e+06  ...       0.000000
# 1                157228.264801               1.975837e+06  ...  485418.609963
# ...

# %%
kenya_pop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 31 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   name                               40 non-null     object
#  1   age_group                          40 non-null     object
#  2   sex                                40 non-null     object
#  3   year                               40 non-null     int64
#  4   population                         40 non-null     float64
#  5   ILO_inactive_share                 40 non-null     float64
#  6   total_inactive_population          40 non-null     float64
#  7   ILO_unemployed_rate                40 non-null     float64
#  8   total_unemployed_population        40 non-null     float64
#  9   total_employed_population          40 non-null     float64
#  10  Agriculture                        40 non-null     float64
# ...

# %%
## Statistical summary
kenya_pop_df.describe()
# Out:
#               year    population  ILO_inactive_share  \
# count    40.000000  4.000000e+01           40.000000
# mean   2019.500000  4.949874e+06           33.440600
# std       2.908872  5.789395e+05           23.952124
# min    2015.000000  4.085026e+06            6.499000
# 25%    2017.000000  4.481412e+06           10.676000
# 50%    2019.500000  4.867160e+06           33.944500
# 75%    2022.000000  5.385925e+06           57.377500
# max    2024.000000  6.063980e+06           58.456000
#
#        total_inactive_population  ILO_unemployed_rate  \
# count               4.000000e+01            40.000000
# mean                1.764240e+06             7.184575
# std                 1.356035e+06             4.718381
# min                 2.682637e+05             1.347000
# 25%                 5.038431e+05             3.392500
# 50%                 1.582808e+06             5.618000
# 75%                 3.114913e+06            12.381750
# ...

# %%
kenya_pop_df.isnull().sum()
# Out:
# name                                 0
# age_group                            0
# sex                                  0
# year                                 0
# population                           0
# ILO_inactive_share                   0
# total_inactive_population            0
# ILO_unemployed_rate                  0
# total_unemployed_population          0
# total_employed_population            0
# Agriculture                          0
# Mining and quarrying                 0
# Manufacturing                        0
# Electricity                          0
# Water supply                         0
# Construction                         0
# Wholesale and retail                 0
# Transport                            0
# Accommodation                        0
# Information and communication        0
# Financial and insurance              0
# Real estate                          0
# Professional                         0
# Administrative and support           0
# ...

# %% [markdown]
# ***We do not have null values in our poplution dataframe***

# %%
kenya_pop_df.columns
# Out:
# Index(['name', 'age_group', 'sex', 'year', 'population', 'ILO_inactive_share',
#        'total_inactive_population', 'ILO_unemployed_rate',
#        'total_unemployed_population', 'total_employed_population',
#        'Agriculture', 'Mining and quarrying', 'Manufacturing', 'Electricity',
#        'Water supply', 'Construction', 'Wholesale and retail', 'Transport',
#        'Accommodation', 'Information and communication',
#        'Financial and insurance', 'Real estate', 'Professional',
#        'Administrative and support', 'Public administration and defence',
#        'Education', 'Human health', 'Arts $ entertainment', 'Other services',
#        'Activities of households', 'Extraterritorial organizations'],
#       dtype='object')

# %%
# check for outliers int the population data

col_names = [
             'total_inactive_population', 'total_unemployed_population',
             'total_employed_population']

fig, ax = plt.subplots(len(col_names), figsize=(6, 6))  # Adjusted figsize
for i, col_val in enumerate(col_names):
    sns.boxplot(x=kenya_pop_df[col_val], ax=ax[i])
    ax[i].set_title('Boxplot - {}'.format(col_val), fontsize=10)
    ax[i].set_xlabel(col_val, fontsize=8)

plt.tight_layout()
plt.show()

# %%
# Column names for comparison
columns_to_compare = ['total_inactive_population', 'ILO_unemployed_rate',
                      'total_unemployed_population', 'total_employed_population']

# Plotting
plt.figure(figsize=(10, 6))

# Plot 'Information and communication' against each column
for col in columns_to_compare:
    plt.plot(kenya_pop_df['year'], kenya_pop_df['Information and communication'], label='Information and communication')
    plt.plot(kenya_pop_df['year'], kenya_pop_df[col], label=col)
    plt.title(f'Comparison of Information and communication with {col}')
    plt.xlabel('Year')
    plt.ylabel('Values from ' + col)  # Update y-axis label to include the column name
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
import matplotlib.pyplot as plt

# Column names for comparison
columns_to_compare = ['total_inactive_population', 'ILO_unemployed_rate',
                      'total_unemployed_population', 'total_employed_population']

# Plotting
plt.figure(figsize=(10, 6))

# Plot each variable against the 'year' column
for col in columns_to_compare:
    plt.plot(kenya_pop_df['year'], kenya_pop_df[col], label=col)

# Customize the plot
plt.title('Trends Comparison Over Time')
plt.xlabel('Year')
plt.ylabel('Values')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ***The above line plots show the the current employment trends for the Kenyan IT sector nationally and by demographics***

# %% [markdown]
# ## Lets use the population data of Ghana and Rwanda to see the trends

# %%
# Column names for comparison
columns_to_compare = ['total_inactive_population', 'ILO_unemployed_rate',
                      'total_unemployed_population', 'total_employed_population']

# Plotting
plt.figure(figsize=(10, 6))

# Plot 'Information and communication' against each column
for col in columns_to_compare:
    plt.plot(rwanda_pop_df['year'], rwanda_pop_df['Information and communication'], label='Information and communication')
    plt.plot(rwanda_pop_df['year'], rwanda_pop_df[col], label=col)
    plt.title(f'Comparison of Information and communication with {col}')
    plt.xlabel('Year')
    plt.ylabel('Values from ' + col)  # Update y-axis label to include the column name
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
ghana_pop_df
# Column names for comparison
columns_to_compare = ['total_inactive_population', 'ILO_unemployed_rate',
                      'total_unemployed_population', 'total_employed_population']

# Plotting
plt.figure(figsize=(10, 6))

# Plot 'Information and communication' against each column
for col in columns_to_compare:
    plt.plot(ghana_pop_df['year'], kenya_pop_df['Information and communication'], label='Information and communication')
    plt.plot(ghana_pop_df['year'], kenya_pop_df[col], label=col)
    plt.title(f'Comparison of Information and communication with {col}')
    plt.xlabel('Year')
    plt.ylabel('Values from ' + col)  # Update y-axis label to include the column name
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
#Using Pearson Correlation
plt.figure(figsize=(12,10))
cor =  kenya_pop_df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %% [markdown]
# ***The heatmap provides a visual representation of the Pearson correlation coefficients between different numeric columns in the kenya_pop_df DataFrame. The color intensity indicates the strength of the correlation: darker shades of red represent stronger positive correlations, while lighter shades or blues represent negative or weak correlations. This visualization can help you identify patterns, relationships, and potential multicollinearity among variables in your dataset.***

# %%
# check for outliers in the education data

col_names = ['Less than basic_unemployment',
             'Basic_unemployment', 'Intermediate_unemployment',
             'Advanced_unemployment']

plt.figure(figsize=(8, 6))  # Adjust the figsize if needed

# Create a violin plot for each column
sns.violinplot(data=kenya_educ_df[col_names], inner="quartile")

plt.title("Violin Plots - Unemployment Education Levels")
plt.xlabel("Education Level")
plt.ylabel("Unemployment")
plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility

plt.tight_layout()
plt.show()

# %%
# Specify the columns for which you want to create histograms
columns_to_plot = ['age_group', 'population', 'total_inactive_population', 'total_unemployed_population']

# Plot histograms for the selected columns
for column in columns_to_plot:
    plt.figure(figsize=(8, 6))
    plt.hist(df[column], bins=10, edgecolor='black')
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

# %%
#Using Pearson Correlation
plt.figure(figsize=(12,10))
cor = kenya_educ_df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %% [markdown]
# ***The heatmap visually represents the correlations between the numeric columns in the kenya_educ_df DataFrame. Darker colors indicate stronger correlations, while lighter colors indicate weaker correlations. Annotations inside the cells provide the exact correlation values. This visualization can help you identify relationships and dependencies between different numeric variables in your dataset.***
